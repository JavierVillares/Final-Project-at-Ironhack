# %%
import pandas as pd

# Load birth rate data
birth_rate_file_path = '/Users/javi/Desktop/Ironhack/Entregas_de_github/Final-Project-at-Ironhack/Data/Raw data/World demographic/BirthRate/birth_rate_first_clean.csv'
birth_rate_data = pd.read_csv(birth_rate_file_path)

# Display the first few rows
print("Birth Rate Data:")
birth_rate_data.head()
# Out:
# Birth Rate Data:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                              Indicator Name  Indicator Code              1960  \
# 0  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN              4.82
# 1  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.72412501084242
# 2  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN             7.282
# 3  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.45844789624312
# 4  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN             6.708
#
#                1961              1962              1963              1964  \
# 0             4.655             4.471             4.271             4.059
# ...

# %%
birth_rate_data.isnull().values.any()
# Out:
# False

# %%
# Load death rate data
death_rate_file_path = '/Users/javi/Desktop/Ironhack/Entregas_de_github/Final-Project-at-Ironhack/Data/Raw data/World demographic/Death rate, crude/death rate.csv'
death_rate_data = pd.read_csv(death_rate_file_path)

# Display the first few rows
print("\nDeath Rate Data:")
death_rate_data.head()
print(death_rate_data.isnull().values.any())
# Out:
# Death Rate Data:
# False

# %%
# Load world population data
world_population_file_path = '/Users/javi/Desktop/Ironhack/Entregas_de_github/Final-Project-at-Ironhack/Data/Raw data/World demographic/world bank population/world_population.csv'
world_population_data = pd.read_csv(world_population_file_path)

# Display the first few rows
print("\nWorld Population Data:")
world_population_data.isnull().values.any()
# Out:
# World Population Data:
# False

# %%
world_population_data.head()
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
#           1968  ...         2013         2014         2015         2016  \
# ...

# %%
birth_rate_data
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 250                       Kosovo          XKX
# 251                  Yemen, Rep.          YEM
# 252                 South Africa          ZAF
# 253                       Zambia          ZMB
# 254                     Zimbabwe          ZWE
#
#                                Indicator Name  Indicator Code  \
# 0    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 1    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 2    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 3    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 4    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# ...

# %%
death_rate_data
# Out:
#                     Country Name       1980       1981       1982       1983  \
# 0                          Aruba   6.060000   5.935000   6.118000   6.253000
# 1    Africa Eastern and Southern  16.680517  16.443989  16.244148  17.621384
# 2                    Afghanistan  24.209000  23.611000  25.622000  25.107000
# 3     Africa Western and Central  18.941439  18.678833  18.449267  18.230465
# 4                         Angola  21.710000  21.462000  21.247000  21.979000
# ..                           ...        ...        ...        ...        ...
# 251                       Kosovo   6.676000   6.494000   6.422000   6.301000
# 252                  Yemen, Rep.  17.608000  16.739000  16.108000  15.009000
# 253                 South Africa   9.810000   9.539000   9.298000   9.075000
# 254                       Zambia  13.520000  13.533000  13.614000  13.828000
# 255                     Zimbabwe  11.069000  10.122000   9.776000   9.442000
#
# ...

# %%
df_long = pd.melt(death_rate_data, id_vars=['Country Name'], var_name='Year', value_name='death_rate_data')

# Convert 'Year' to an integer
df_long['Year'] = df_long['Year'].astype(int)

df_sorted = df_long.sort_values(by='Country Name')
